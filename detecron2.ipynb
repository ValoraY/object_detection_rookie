# %% [markdown]
# <a href="https://colab.research.google.com/github/ValoraY/object_detection_rookie/blob/main/detecron2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1.安装依赖

# %%
# !unzip '/content/drive/MyDrive/AI_content/detectron2-main.zip' -d '/content/drive/MyDrive/AI_content/FasterRCNN'

# %%
# %pwd
# Out:
# '/content'

# %%
cd /content/drive/MyDrive/AI_content/FasterRCNN/detectron2-main
# Out:
# /content/drive/MyDrive/AI_content/FasterRCNN/detectron2-main

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/AI_content/FasterRCNN/detectron2-main'

# %%
pip list

# %%
# 在当前目录下安装当前项目（当前目录的代码）作为一个可编辑（editable）的包
# "pip install -e ."会在当前目录中查找setup.py文件，并尝试使用其中的信息来安装当前项目
# setup.py是一个包含有关项目元数据（如名称、版本、依赖项等）的文件，它描述了如何安装当前项目
pip install -e .

# %% [markdown]
# # 2.Inference Demo

# %%
cd demo/
# Out:
# /content/drive/MyDrive/AI_content/FasterRCNN/detectron2-main/demo

# %%
# !python demo.py --config-file ../configs/COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml \
  --input ../JY_inputs_test/000000000285.jpg ../JY_inputs_test/000000000724.jpg \
  --output ../JY_outputs_test/ \
  --opts MODEL.WEIGHTS detectron2://COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x/137849600/model_final_f10217.pkl

# %% [markdown]
# # 3.Prepare data

# %%
# 准备pascal_voc_2007数据集
# !unzip '/content/drive/MyDrive/AI_content/VOC2007.zip' -d '/content/drive/MyDrive/AI_content/FasterRCNN/detectron2-main/datasets'

# %% [markdown]
# # 3.Train

# %%
cd ..
# Out:
# /content/drive/MyDrive/AI_content/FasterRCNN/detectron2-main

# %%
# 训练PascalVOC数据集配置文件： /content/drive/MyDrive/AI_content/FasterRCNN/detectron2-main/configs/PascalVOC-Detection/faster_rcnn_R_50_FPN.yaml
# 这里修改了配置文件faster_rcnn_R_50_FPN.yaml
# TRAIN: ('voc_2007_trainval','voc_2012_trainval') ==> TRAIN: ('voc_2007_trainval',) 注意"，"不能删除
# 注意在运行下一行的训练代码前要回到当前项目目录下
# !python tools/train_net.py \
  --config-file configs/PascalVOC-Detection/faster_rcnn_R_50_FPN.yaml \
  --num-gpus 1 SOLVER.IMS_PER_BATCH 2 SOLVER.BASE_LR 0.0025
# Out:
# Command Line Args: Namespace(config_file='configs/PascalVOC-Detection/faster_rcnn_R_50_FPN.yaml', resume=False, eval_only=False, num_gpus=1, num_machines=1, machine_rank=0, dist_url='tcp://127.0.0.1:49152', opts=['SOLVER.IMS_PER_BATCH', '2', 'SOLVER.BASE_LR', '0.0025'])
# [12/21 07:16:00 detectron2]: Rank of current process: 0. World size: 1
# [12/21 07:16:01 detectron2]: Environment info:
# -------------------------------  ----------------------------------------------------------------------------
# sys.platform                     linux
# Python                           3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# numpy                            1.23.5
# detectron2                       0.6 @/content/drive/MyDrive/AI_content/FasterRCNN/detectron2-main/detectron2
# Compiler                         GCC 11.4
# CUDA compiler                    CUDA 12.2
# detectron2 arch flags            7.5
# DETECTRON2_ENV_MODULE            <not set>
# ...

# %%
# 重启运行时
import os
os.kill(os.getpid(), 9)
